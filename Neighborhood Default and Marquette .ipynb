# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()

from matplotlib.collections import PatchCollection
from matplotlib.patches import PathPatch, Polygon
from mpl_toolkits.basemap import Basemap

# %matplotlib inline

# %%
df= pd.read_csv('gis_mke_with_nei.csv')
df.head()
# Out:
#    Unnamed: 0  g_case_no      y_lat      x_lng  \
# 0           0   11000001  43.091474 -87.984090
# 1           1   11000002  43.068454 -87.918139
# 2           2   11000009  43.122443 -88.014475
# 3           3   11000014  43.056875 -87.941243
# 4           4   11000024  43.054717 -87.936219
#
#                               f_addr  \
# 0    5700 W CAPITOL DR MILWAUKEE, WI
# 1        2736 N 6TH ST MILWAUKEE, WI
# 2  8223 W THURSTON AVE MILWAUKEE, WI
# 3         2020 N 23 ST MILWAUKEE, WI
# 4         1840 N 19 ST MILWAUKEE, WI
#
#                                          gf_addr          c_case_type  \
# 0    5700 W Capitol Dr, Milwaukee, WI 53216, USA   Municipal citation
# 1        2736 N 6th St, Milwaukee, WI 53212, USA   Municipal citation
# 2  8223 W Thurston Ave, Milwaukee, WI 53218, USA  Summons & Complaint
# 3       2020 N 23rd St, Milwaukee, WI 53205, USA  Summons & Complaint
# 4       1840 N 19th St, Milwaukee, WI 53205, USA  Summons & Complaint
#
# ...

# %%
finding_count = df["neighborhood"].value_counts()
finding_count
# Out:
# East Town                   5928
# Westown                     3728
# Park West                   3631
# Harambee                    3514
# Old North Milwaukee         3448
# Franklin Heights            3349
# Historic Mitchell Street    3305
# Avenues West                3240
# Walker's Point              2984
# Lindsay Heights             2807
# Bay View                    2722
# Silver Spring               2638
# Capitol Heights             2633
# Clarke Square               2616
# Lincoln Village             2610
# Lincoln Creek               2336
# Williamsburg Heights        2290
# Midtown                     2251
# Southgate                   2197
# Riverwest                   2184
# Sherman Park                2084
# Muskego Way                 1832
# North Division              1778
# Roosevelt Grove             1772
# Metcalfe Park               1758
# Uptown                      1701
# Lower East Side             1696
# Washington Park             1470
# ...

# %%
case =  df["c_case_type"].value_counts()
case
# Out:
# Municipal citation     103887
# Traffic citation        16391
# Summons & Complaint     10165
# Contempt                    1
# Name: c_case_type, dtype: int64

# %%
MU = df[df.neighborhood == 'Marquette']
MU.head()
# Out:
#        Unnamed: 0  g_case_no      y_lat      x_lng  \
# 1732         1732   11026338  43.039022 -87.927068
# 10581       10594   11116965  43.038283 -87.932680
# 11011       11025   11120164  43.036151 -87.932964
# 16625       16640   12027378  43.038604 -87.927439
# 16626       16641   12027379  43.038604 -87.927439
#
#                                    f_addr  \
# 1732   1176 W WISCONSIN AVE MILWAUKEE, WI
# 10581  1535 W WISCONSIN AVE MILWAUKEE, WI
# 11011       1600 W CLYBOURN MILWAUKEE, WI
# 16625  1201 W WISCONSIN AVE MILWAUKEE, WI
# 16626  1201 W WISCONSIN AVE MILWAUKEE, WI
#
#                                               gf_addr         c_case_type  \
# 1732   1176 W Wisconsin Ave, Milwaukee, WI 53233, USA  Municipal citation
# 10581  1535 W Wisconsin Ave, Milwaukee, WI 53233, USA  Municipal citation
# 11011    1600 W Clybourn St, Milwaukee, WI 53233, USA  Municipal citation
# 16625  1201 W Wisconsin Ave, Milwaukee, WI 53233, USA  Municipal citation
# ...

# %%
case =  MU["j_finding"].value_counts()
case
# Out:
# Guilty                         15
# Dismissed without Prejudice     2
# Name: j_finding, dtype: int64

# %%
case = MU["c_violation"].value_counts()
case
# Out:
# Ordinance 110-10-1, Trespassing Upon Buildings / Premises        4
# Ordinance 105-2, Assault and Battery                             3
# Ordinance 106-1.8-1, Public Drinking                             2
# Ordinance 106-1-1, Disorderly Conduct                            2
# Ordinance 106-5-2, Indecent Exposure                             1
# Ordinance 105-34-1-a, Carrying Concealed and Dangerous Weapon    1
# Ordinance 106-31-1, Loitering or Prowling                        1
# Ordinance 106-11, Mashing                                        1
# Ordinance 106-1.8-1, Public Drinking Prohibited                  1
# Ordinance 106-51-3-a, Designated Offender Residency Restricts    1
# Name: c_violation, dtype: int64
