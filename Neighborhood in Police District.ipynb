# %%
print(n.index)
# Out:
# Int64Index([     0,      1,      2,      3,      4,      5,      7,     11,
#                 14,     15,
#             ...
#              20578,  22687,  24422,  26409,  31640,  38357,  56675,  57022,
#              92218, 111111],
#            dtype='int64', length=190)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns; sns.set()

from matplotlib.collections import PatchCollection
from matplotlib.patches import PathPatch, Polygon
from mpl_toolkits.basemap import Basemap

# %matplotlib inline

dir = '/Users/Dominique/'

fig = plt.figure(figsize = (15, 10), dpi = 300)  
#ax = fig.add_subplot(111)

map = Basemap(projection = 'cyl',
              resolution = 'h',
              lat_0 = 43.0389025,
              lon_0 = -87.9064736,
              llcrnrlon = -88.080736,
              llcrnrlat = 42.917670,
              urcrnrlon = -87.839722,
              urcrnrlat = 43.19712)

#map.readshapefile(dir + 'mke_st/mke_st',
#                  name = 'st',
#                  color = '#f8f8ff',
#                  linewidth = 0.5)

#map.readshapefile(dir + 'mke_ald/mke_ald',
#                  name = 'ald',
#                  color = '#7b68ee',
#                  linewidth = 0.75)

map.readshapefile(dir + 'police_dis',
                  name = 'ald',
                  color = '#003366',
                  linewidth = 0.75)

#pat_ald = []

#for info, shape in zip(map.ald_info, map.ald):
#    if info['OBJECTID'] != None:
#        pat_ald.append(Polygon(np.array(shape), True))

#ax.add_collection(PatchCollection(pat_ald,
#                                 facecolor = '#ebe3cd',
#                                 edgecolor = 'yellow',
#                                 linewidths = 1.5,
#                                 zorder = 2))

#pat_st = []

#for info, shape in zip(map.st_info, map.st):
#    if info['DIR'] != None:
#        pat_st.append(Polygon(np.array(shape), True))

#ax.add_collection(PatchCollection(pat_st,
#                                 facecolor = '#f8f8ff',
#                                 edgecolor = '#f8f8ff',
#                                 linewidths = 0.5,
#                                 zorder = 2))


    
df= pd.read_csv('gis_mke_with_nei.csv')

df1= df.drop_duplicates(["neighborhood"], keep="first")

plt.subplots_adjust(bottom = 0.1)

plt.scatter(df1["x_lng"], df1['y_lat'])

for i in range(0,df1.shape[0]):
     plt.annotate(df1.neighborhood.iloc[i],(df1.x_lng.iloc[i], df1.y_lat.iloc[i]),textcoords='offset points', ha='center', va='center',
        bbox=dict(boxstyle='round,pad=0.5', fc='yellow', alpha=0.5),
        arrowprops=dict(arrowstyle = '->', connectionstyle='arc3,rad=0'))
# plt.axis('off')
# plt.xlabel(None)
# plt.ylabel(None)
    
plt.show()
# Out:
# C:\Users\Dominique\Anaconda3\lib\site-packages\matplotlib\text.py:2096: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.
#   warnings.warn("You have used the `textcoords` kwarg, but not "
# C:\Users\Dominique\Anaconda3\lib\site-packages\matplotlib\text.py:2096: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.
#   warnings.warn("You have used the `textcoords` kwarg, but not "
# C:\Users\Dominique\Anaconda3\lib\site-packages\matplotlib\text.py:2096: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.
#   warnings.warn("You have used the `textcoords` kwarg, but not "
# C:\Users\Dominique\Anaconda3\lib\site-packages\matplotlib\text.py:2096: UserWarning: You have used the `textcoords` kwarg, but not the `xytext` kwarg.  This can lead to surprising results.
# ...
